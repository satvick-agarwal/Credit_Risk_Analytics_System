# %%
import pandas as pd

# %%
df=pd.read_csv("D://BATTLEGROUNDS//Credit_Risk_Analytics_System//data//processed//cleaned_data.csv")

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0             0.486462                         3.0           561
# ...

# %%
df["person_gender"].value_counts()
# Out:
# person_gender
# male      24832
# female    20156
# Name: count, dtype: int64

# %%
bins = [18, 25, 35, 50, 65, 100]
labels = ["18-25", "26-35", "36-50", "51-65", "65+"]

df["age_group"] = pd.cut(df["person_age"], bins=bins, labels=labels)

# %%
df["age_group"].value_counts()
# Out:
# age_group
# 18-25    20441
# 26-35    20073
# 36-50     4158
# 51-65      289
# 65+         27
# Name: count, dtype: int64

# %%
df["person_education"].value_counts()
# Out:
# person_education
# Bachelor       13395
# Associate      12025
# High School    11967
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df["person_home_ownership"].value_counts()
# Out:
# person_home_ownership
# RENT        23436
# MORTGAGE    18484
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
df["loan_intent"].value_counts()
# Out:
# loan_intent
# EDUCATION            9151
# MEDICAL              8544
# VENTURE              7815
# PERSONAL             7550
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df["loan_status"].value_counts(normalize=True)
# Out:
# loan_status
# 0    0.777719
# 1    0.222281
# Name: proportion, dtype: float64

# %%
df["age_group"] = pd.cut(df["person_age"], bins=[18,25,35,50,65,100])
df.groupby("age_group")["loan_status"].mean()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_12656\2235635808.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("age_group")["loan_status"].mean()
# age_group
# (18, 25]     0.233942
# (25, 35]     0.213122
# (35, 50]     0.206109
# (50, 65]     0.269896
# (65, 100]    0.185185
# Name: loan_status, dtype: float64

# %%
df.groupby("person_gender")["loan_status"].mean()
# Out:
# person_gender
# female    0.222514
# male      0.222092
# Name: loan_status, dtype: float64

# %%
df.groupby("person_education")["loan_status"].mean()
# Out:
# person_education
# Associate      0.220374
# Bachelor       0.225308
# Doctorate      0.228663
# High School    0.223197
# Master         0.217622
# Name: loan_status, dtype: float64

# %%
df.groupby("person_home_ownership")["loan_status"].mean()
# Out:
# person_home_ownership
# MORTGAGE    0.115992
# OTHER       0.333333
# OWN         0.075229
# RENT        0.324074
# Name: loan_status, dtype: float64

# %%
df.groupby("loan_intent")["loan_status"].mean()
# Out:
# loan_intent
# DEBTCONSOLIDATION    0.302729
# EDUCATION            0.169599
# HOMEIMPROVEMENT      0.263015
# MEDICAL              0.278324
# PERSONAL             0.201457
# VENTURE              0.144338
# Name: loan_status, dtype: float64

# %%
df.groupby("previous_loan_defaults_on_file")["loan_status"].mean()
# Out:
# previous_loan_defaults_on_file
# No     0.451814
# Yes    0.000000
# Name: loan_status, dtype: float64

# %%
df.groupby(pd.cut(df["loan_percent_income"], bins=5))["loan_status"].mean()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_12656\919316313.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["loan_percent_income"], bins=5))["loan_status"].mean()
# loan_percent_income
# (-5.92e-06, 0.133]    0.125347
# (0.133, 0.266]        0.240952
# (0.266, 0.399]        0.705301
# (0.399, 0.531]        0.752193
# (0.531, 0.664]        0.689655
# Name: loan_status, dtype: float64

# %%
df.groupby(pd.cut(df["person_income"], bins=5))["loan_status"].mean()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_12656\3390905020.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["person_income"], bins=5))["loan_status"].mean()
# person_income
# (5559.339, 496132.2]      0.222475
# (496132.2, 984264.4]      0.177215
# (984264.4, 1472396.6]     0.000000
# (1472396.6, 1960528.8]    0.000000
# (1960528.8, 2448661.0]    0.000000
# Name: loan_status, dtype: float64

# %%
df.groupby(pd.cut(df["loan_amnt"], bins=5))["loan_status"].mean()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_12656\2518389903.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df["loan_amnt"], bins=5))["loan_status"].mean()
# loan_amnt
# (465.5, 7400.0]       0.190773
# (7400.0, 14300.0]     0.207295
# (14300.0, 21200.0]    0.297260
# (21200.0, 28100.0]    0.360949
# (28100.0, 35000.0]    0.361842
# Name: loan_status, dtype: float64
