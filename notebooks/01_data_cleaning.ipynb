# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\BATTLEGROUNDS\\Credit_Risk_Analytics_System\\data\\raw\\loan_data.csv')

# %%
df.shape
# Out:
# (45000, 14)

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df.describe(include='object')
# Out:
#        person_gender person_education person_home_ownership loan_intent  \
# count          45000            45000                 45000       45000
# unique             2                5                     4           6
# top             male         Bachelor                  RENT   EDUCATION
# freq           24841            13399                 23443        9153
#
#        previous_loan_defaults_on_file
# count                           45000
# unique                              2
# top                               Yes
# freq                            22858

# %%
df["person_gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df["person_education"].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df["person_home_ownership"].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
df["loan_intent"].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
df["previous_loan_defaults_on_file"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df[(df['person_age'] > 75) | (df['person_age'] < 18)].shape[0]
# Out:
# 12

# %% [markdown]
# """12 rows invalid"""

# %%
df[df["person_emp_exp"]>df["person_age"]-14].shape[0]
# Out:
# 0

# %%
df[(df["loan_percent_income"] <= 0) | (df["loan_percent_income"] > 1)].shape[0]
# Out:
# 27

# %% [markdown]
# """27 rows invalid"""

# %%
df[df["cb_person_cred_hist_length"] > df["person_age"]].shape[0]
# Out:
# 0

# %%
df[(df["credit_score"] < 300) | (df["credit_score"] > 850)].shape[0]
# Out:
# 0

# %%
df["calc_ratio"] = df["loan_amnt"] / df["person_income"]

(df["loan_percent_income"] - df["calc_ratio"]).abs().describe()
# Out:
# count    45000.000000
# mean         0.002525
# std          0.001434
# min          0.000000
# 25%          0.001300
# 50%          0.002534
# 75%          0.003764
# max          0.005030
# dtype: float64

# %%
for col in ["person_home_ownership", "loan_intent", "previous_loan_defaults_on_file"]:
    print(col, df[col].unique())
# Out:
# person_home_ownership ['RENT' 'OWN' 'MORTGAGE' 'OTHER']
# loan_intent ['PERSONAL' 'EDUCATION' 'MEDICAL' 'VENTURE' 'HOMEIMPROVEMENT'
#  'DEBTCONSOLIDATION']
# previous_loan_defaults_on_file ['No' 'Yes']
